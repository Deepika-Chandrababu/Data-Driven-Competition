# %%
setwd("C:/Users/Deepika Chandrababu/Desktop/SML")

# %%
training_values <- read.csv("C:/Users/Deepika Chandrababu/Desktop/SML/training values.csv", sep=",")

# %%
training_labels <- read.csv("training labels.csv", sep=",")

# %%
head(training_values)
# Out:
#   id    amount_tsh date_recorded funder              gps_height installer
# 1 69572 6000       2011-03-14    Roman               1390       Roman
# 2  8776    0       2013-03-06    Grumeti             1399       GRUMETI
# 3 34310   25       2013-02-25    Lottery Club         686       World vision
# 4 67743    0       2013-01-28    Unicef               263       UNICEF
# 5 19728    0       2011-07-13    Action In A            0       Artisan
# 6  9944   20       2011-03-13    Mkinga Distric Coun    0       DWE
#   longitude latitude   wpt_name             num_private ... payment_type
# 1 34.93809   -9.856322 none                 0           ... annually
# 2 34.69877   -2.147466 Zahanati             0           ... never pay
# 3 37.46066   -3.821329 Kwa Mahundi          0           ... per bucket
# 4 38.48616  -11.155298 Zahanati Ya Nanyumbu 0           ... never pay
# 5 31.13085   -1.825359 Shuleni              0           ... never pay
# ...

# %%
head(training_labels)
# Out:
#   id    status_group
# 1 69572 functional
# 2  8776 functional
# 3 34310 functional
# 4 67743 non functional
# 5 19728 functional
# 6  9944 functional

# %%
testing_values <- read.csv("test values.csv",sep=",")

# %%
summary(training_values)
# Out:
#        id          amount_tsh       date_recorded         funder
#  Min.   :    0   Min.   :     0.0   Length:59400       Length:59400
#  1st Qu.:18520   1st Qu.:     0.0   Class :character   Class :character
#  Median :37062   Median :     0.0   Mode  :character   Mode  :character
#  Mean   :37115   Mean   :   317.7
#  3rd Qu.:55657   3rd Qu.:    20.0
#  Max.   :74247   Max.   :350000.0
#    gps_height      installer           longitude        latitude
#  Min.   : -90.0   Length:59400       Min.   : 0.00   Min.   :-11.649
#  1st Qu.:   0.0   Class :character   1st Qu.:33.09   1st Qu.: -8.541
#  Median : 369.0   Mode  :character   Median :34.91   Median : -5.022
#  Mean   : 668.3                      Mean   :34.08   Mean   : -5.706
#  3rd Qu.:1319.2                      3rd Qu.:37.18   3rd Qu.: -3.326
#  Max.   :2770.0                      Max.   :40.35   Max.   :  0.000
#    wpt_name          num_private           basin            subvillage
# ...

# %%
summary(training_labels)
# Out:
#        id        status_group
#  Min.   :    0   Length:59400
#  1st Qu.:18520   Class :character
#  Median :37062   Mode  :character
#  Mean   :37115
#  3rd Qu.:55657
#  Max.   :74247

# %%
library(ggplot2)
library(tidyverse)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 4.0.5"
# Warning message:
# "package 'tidyverse' was built under R version 4.0.5"
# -- Attaching packages --------------------------------------- tidyverse 1.3.1 --
#
# v tibble  3.1.0     v dplyr   1.0.5
# v tidyr   1.1.3     v stringr 1.4.0
# v readr   1.4.0     v forcats 0.5.1
# v purrr   0.3.4
#
# Warning message:
# "package 'tibble' was built under R version 4.0.5"
# Warning message:
# "package 'tidyr' was built under R version 4.0.5"
# Warning message:
# "package 'readr' was built under R version 4.0.5"
# Warning message:
# "package 'purrr' was built under R version 4.0.5"
# Warning message:
# "package 'dplyr' was built under R version 4.0.5"
# Warning message:
# "package 'stringr' was built under R version 4.0.5"
# Warning message:
# "package 'forcats' was built under R version 4.0.5"
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# ...

# %%
merge <- merge(training_values, training_labels)

# %%
head(merge)
# Out:
#   id amount_tsh date_recorded funder          gps_height installer longitude
# 1 0   0         2012-11-13    Tasaf              0       TASAF     33.12583
# 2 1   0         2011-03-05    Shipo           1978       SHIPO     34.77072
# 3 2   0         2011-03-27    Lvia               0       LVIA      36.11506
# 4 3  10         2013-06-03    Germany Republi 1639       CES       37.14743
# 5 4   0         2011-03-22    Cmsr               0       CMSR      36.16489
# 6 5  50         2011-02-26    Private           28       Private   39.28612
#   latitude  wpt_name       num_private ... water_quality quality_group
# 1 -5.118154 Mratibu        0           ... milky         milky
# 2 -9.395642 none           0           ... soft          good
# 3 -6.279268 Bombani        0           ... soft          good
# 4 -3.187555 Area 7 Namba 5 0           ... soft          good
# 5 -6.099289 Ezeleda        0           ... soft          good
# ...

# %%
counts<-table(merge$status_group,merge$basin)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$amount_tsh)
barplot(counts, main="Basin vs Statusgroup", xlab="Amount", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$water_quality)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.5),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$date_recorded)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$funder)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$gps_height)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$installer)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$latitude)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$longitude)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$wpt_name)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$num_private)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$water_quality)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$quality_group)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$quantity)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$quantity_group)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$source)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$source_type)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$source_class)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$waterpoint_type)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$waterpoint_type_group)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$management)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$management_group)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$payment)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$payment_type)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$scheme_management)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$scheme_name)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$permit)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$construction_year)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$ward)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$population)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$public_meeting)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$recorded_by)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$region)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$region_code)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$district_code)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$lga)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$subvillage)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$installer)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$extraction_type)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$extraction_type_group)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"

# %%
counts<-table(merge$status_group,merge$extraction_type_class)
barplot(counts, main="Basin vs Statusgroup", xlab="basin", ylab="total",col=c("lightgreen","brown","purple"),
       legend.text=rownames(counts), args.legend=list(cex=0.7),beside=TRUE)
# Out:
# Plot with title "Basin vs Statusgroup"
